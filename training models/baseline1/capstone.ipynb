# %% [markdown]
# # Read Dataset

# %%
import pandas as pd

# Baca data dari file CSV
df = pd.read_csv('mntl.csv')

# Tampilkan dataframe
print(df.head())
# Out:
#    Unnamed: 0       tag                  patterns  \
# 0           0  greeting                        Hi
# 1           1  greeting                       Hey
# 2           2  greeting  Apakah ada orang disana?
# 3           3  greeting                      Halo
# 4           4  greeting                     Hello
#
#                                            responses
# 0  ['Halo. Ceritakan bagaimana perasaan Anda hari...
# 1  ['Halo. Ceritakan bagaimana perasaan Anda hari...
# 2  ['Halo. Ceritakan bagaimana perasaan Anda hari...
# 3  ['Halo. Ceritakan bagaimana perasaan Anda hari...
# 4  ['Halo. Ceritakan bagaimana perasaan Anda hari...

# %% [markdown]
# # Preprocessing

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# Convert 'patterns' column to strings
df['patterns'] = df['patterns'].astype(str)

# Tokenisasi dan pad sequences
tokenizer = Tokenizer(lower=True, split=' ')
tokenizer.fit_on_texts(df['patterns'])
vacab_size = len(tokenizer.word_index)

ptrn2seq = tokenizer.texts_to_sequences(df['patterns'])
X = pad_sequences(ptrn2seq, padding='post')

# Label encoding untuk variabel target
lbl_enc = LabelEncoder()
y = lbl_enc.fit_transform(df['tag'])

# %% [markdown]
# # Training Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Embedding, LSTM, LayerNormalization, Dense, Dropout
import numpy as np

model = Sequential([
          Input(shape=(X.shape[1],)),  # Fix: Added comma in the shape tuple
          # Embedding layer

          Embedding(input_dim=vacab_size + 1, output_dim=100),
          # LSTM layers
          LayerNormalization(),
          LSTM(32, return_sequences=True),
          LayerNormalization(),
          LSTM(32, return_sequences=True),
          LSTM(32),
          LayerNormalization(),

          # Dense layers
          LayerNormalization(),
          Dense(128, activation="relu"),
          Dropout(0.2),

          LayerNormalization(),
          Dense(128, activation="relu"),
          Dropout(0.2),
          Dense(len(np.unique(y)), activation="softmax")
])


model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=['accuracy'])

history = model.fit(x=X, y=y, batch_size=10, epochs=50)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 8s 64ms/step - loss: 4.5818 - accuracy: 0.0096
# Epoch 2/50
# 32/32 [==============================] - 1s 33ms/step - loss: 4.4591 - accuracy: 0.0225
# Epoch 3/50
# 32/32 [==============================] - 1s 27ms/step - loss: 4.4320 - accuracy: 0.0225
# Epoch 4/50
# 32/32 [==============================] - 1s 42ms/step - loss: 4.3137 - accuracy: 0.0289
# Epoch 5/50
# 32/32 [==============================] - 1s 26ms/step - loss: 4.2470 - accuracy: 0.0354
# Epoch 6/50
# 32/32 [==============================] - 0s 14ms/step - loss: 4.1649 - accuracy: 0.0354
# Epoch 7/50
# 32/32 [==============================] - 0s 12ms/step - loss: 3.9359 - accuracy: 0.0322
# Epoch 8/50
# 32/32 [==============================] - 0s 14ms/step - loss: 3.8522 - accuracy: 0.0482
# Epoch 9/50
# 32/32 [==============================] - 0s 14ms/step - loss: 3.7380 - accuracy: 0.0772
# Epoch 10/50
# 32/32 [==============================] - 0s 11ms/step - loss: 3.5394 - accuracy: 0.0900
# Epoch 11/50
# 32/32 [==============================] - 0s 11ms/step - loss: 3.2640 - accuracy: 0.1222
# Epoch 12/50
# 32/32 [==============================] - 0s 11ms/step - loss: 3.0036 - accuracy: 0.1833
# Epoch 13/50
# 32/32 [==============================] - 0s 11ms/step - loss: 2.8545 - accuracy: 0.2283
# Epoch 14/50
# 32/32 [==============================] - 1s 17ms/step - loss: 2.5560 - accuracy: 0.2701
# Epoch 15/50
# 32/32 [==============================] - 0s 12ms/step - loss: 2.3399 - accuracy: 0.2990
# Epoch 16/50
# 32/32 [==============================] - 0s 11ms/step - loss: 2.1200 - accuracy: 0.3441
# Epoch 17/50
# 32/32 [==============================] - 0s 12ms/step - loss: 1.8222 - accuracy: 0.4695
# Epoch 18/50
# 32/32 [==============================] - 0s 12ms/step - loss: 1.8202 - accuracy: 0.4212
# Epoch 19/50
# 32/32 [==============================] - 0s 12ms/step - loss: 1.6008 - accuracy: 0.5177
# Epoch 20/50
# 32/32 [==============================] - 1s 20ms/step - loss: 1.3313 - accuracy: 0.6270
# Epoch 21/50
# 32/32 [==============================] - 0s 15ms/step - loss: 1.3382 - accuracy: 0.5659
# Epoch 22/50
# 32/32 [==============================] - 0s 12ms/step - loss: 1.0907 - accuracy: 0.6720
# Epoch 23/50
# 32/32 [==============================] - 0s 14ms/step - loss: 0.9880 - accuracy: 0.7074
# Epoch 24/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.8204 - accuracy: 0.7395
# Epoch 25/50
# 32/32 [==============================] - 1s 20ms/step - loss: 0.7348 - accuracy: 0.7846
# Epoch 26/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.6097 - accuracy: 0.8360
# Epoch 27/50
# 32/32 [==============================] - 0s 14ms/step - loss: 0.5584 - accuracy: 0.8264
# Epoch 28/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.6325 - accuracy: 0.8103
# Epoch 29/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.4636 - accuracy: 0.8842
# Epoch 30/50
# 32/32 [==============================] - 1s 21ms/step - loss: 0.3415 - accuracy: 0.9068
# Epoch 31/50
# 32/32 [==============================] - 1s 22ms/step - loss: 0.3090 - accuracy: 0.9196
# Epoch 32/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2179 - accuracy: 0.9421
# Epoch 33/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1834 - accuracy: 0.9743
# Epoch 34/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1660 - accuracy: 0.9678
# Epoch 35/50
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1531 - accuracy: 0.9678
# Epoch 36/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1527 - accuracy: 0.9743
# Epoch 37/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1380 - accuracy: 0.9678
# Epoch 38/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1019 - accuracy: 0.9807
# Epoch 39/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1032 - accuracy: 0.9871
# Epoch 40/50
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1346 - accuracy: 0.9711
# Epoch 41/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1606 - accuracy: 0.9614
# Epoch 42/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1812 - accuracy: 0.9582
# Epoch 43/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1278 - accuracy: 0.9678
# Epoch 44/50
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1177 - accuracy: 0.9775
# Epoch 45/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1115 - accuracy: 0.9678
# Epoch 46/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1177 - accuracy: 0.9678
# Epoch 47/50
# 32/32 [==============================] - 0s 15ms/step - loss: 0.1041 - accuracy: 0.9775
# Epoch 48/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1230 - accuracy: 0.9743
# Epoch 49/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1444 - accuracy: 0.9614
# Epoch 50/50
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1737 - accuracy: 0.9518

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 23, 100)           36000
#
#  layer_normalization_5 (Lay  (None, 23, 100)           200
#  erNormalization)
#
#  lstm_3 (LSTM)               (None, 23, 32)            17024
#
#  layer_normalization_6 (Lay  (None, 23, 32)            64
#  erNormalization)
#
#  lstm_4 (LSTM)               (None, 23, 32)            8320
#
#  lstm_5 (LSTM)               (None, 32)                8320
#
#  layer_normalization_7 (Lay  (None, 32)                64
#  erNormalization)
#
#  layer_normalization_8 (Lay  (None, 32)                64
#  erNormalization)
#
#  dense_3 (Dense)             (None, 128)               4224
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  layer_normalization_9 (Lay  (None, 128)               256
#  erNormalization)
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 80)                10320
#
# =================================================================
# Total params: 101368 (395.97 KB)
# Trainable params: 101368 (395.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True)

# %% [markdown]
# ## Training Result Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Plot training accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Save Model

# %%
model.save("model1.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pickle

with open('tokenizer.pkl', 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

with open('maxlen.pkl', 'wb') as maxlen_file:
    pickle.dump(X, maxlen_file)

with open('lbl_enc.pkl', 'wb') as lbl_enc_file:
    pickle.dump(lbl_enc, lbl_enc_file)

with open('model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)

# %% [markdown]
# # Model Testing

# %%
import re
import random

def generate_answer(pattern):
    text = []
    txt = re.sub('[^a-zA-Z\']', ' ', pattern)
    txt = txt.lower()
    txt = txt.split()
    txt = " ".join(txt)
    text.append(txt)

    # Tokenize and pad the input sequence
    x_test = tokenizer.texts_to_sequences(text)
    x_test = pad_sequences(x_test, padding='post', maxlen=X.shape[1])

    # Make predictions
    y_pred = model.predict(x_test)
    predicted_class = np.argmax(y_pred, axis=-1)
    tag = lbl_enc.inverse_transform(predicted_class)[0]

    # Get responses associated with the selected tag
    responses = df[df['tag'] == tag]['responses'].values

    if len(responses) > 0:
        # If there are responses, choose a random one
        response = random.choice(responses)
        if isinstance(response, np.ndarray):
            # Convert numpy array to string
            response = response[0]
    else:
        # If no responses are found, provide a default message
        response = "Maafkan saya, saya tidak mengerti hal itu."

    print("you: {}".format(pattern))
    print("model: {}".format(response))

generate_answer('Hai! Apa Kabar?')
# Out:
# 1/1 [==============================] - 1s 1s/step
# you: Hai! Apa Kabar?
# model: ['Halo. Ceritakan bagaimana perasaan Anda hari ini?', 'Hai. Apa yang membawamu kemari hari ini?', 'Hai. Bagaimana perasaan Anda hari ini?', 'Senang bertemu dengan Anda. Bagaimana perasaan Anda saat ini?', 'Halo. Senang melihat Anda kembali. Apa yang sedang terjadi di duniamu saat ini?']

# %%
generate_answer('Kamu siapa')
# Out:
# 1/1 [==============================] - 0s 21ms/step
# you: Kamu siapa
# model: ['Saya Kenari, Asisten AI Terapi Pribadi Anda. Bagaimana perasaan Anda hari ini', 'Saya Kenari, AI Terapi Asisten yang dirancang untuk membantu Anda. Ceritakan tentang diri Anda.', 'Saya Kenari. Saya adalah agen percakapan yang dirancang untuk meniru terapis. Jadi, bagaimana perasaan Anda hari ini?', 'Anda bisa memanggil saya Kenari.', 'Saya Kenari!', 'Panggil saya Kenari']

# %%
generate_answer('Siapa yang menciptakanmu?')
# Out:
# 1/1 [==============================] - 0s 21ms/step
# you: Siapa yang menciptakanmu?
# model: ['Saya diciptakan oleh Tim CH2-PS130 Capstone Project Program Bangkit Academy 2023 Batch 2.', 'Saya dilatih menggunakan dataset teks dengan teknik Deep Learning & Natural Language Processing.', 'Saya diciptakan oleh Tim CH2-PS130 Capstone Project Program Bangkit Academy 2023 Batch 2. Saya dilatih menggunakan dataset teks dengan teknik Deep Learning & Natural Language Processing.']

# %%
generate_answer('Saya pikir saya depresi.')
# Out:
# 1/1 [==============================] - 0s 21ms/step
# you: Saya pikir saya depresi.
# model: ['Bicarakan tentang apa yang sedang terjadi. Anda akan baik-baik saja.', 'Bicaralah padaku. Ceritakan lebih banyak. Membuka diri kepada orang lain bisa membantu.', 'Terkadang ketika kita depresi, sulit untuk peduli tentang apapun. Sulit untuk melakukan hal-hal yang paling sederhana. Beri diri Anda waktu untuk sembuh.']
